# %%
# Install required python libraries
import os

# Install PyTorch Geometric and other libraries
if 'IS_GRADESCOPE_ENV' not in os.environ:
    print("Installing PyTorch Geometric")
    # !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-2.1.0+cu121.html
    # !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-2.1.0+cu121.html
    # !pip install -q torch-geometric
    print("Installing other libraries")
    # !pip install networkx
    # !pip install lovely-tensors
# Out:
# Installing PyTorch Geometric
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 88.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 33.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.8 MB/s eta 0:00:00
# Installing other libraries
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Collecting lovely-tensors
#   Downloading lovely_tensors-0.1.15-py3-none-any.whl (17 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from lovely-tensors) (2.1.0+cu121)
# Collecting lovely-numpy>=0.2.9 (from lovely-tensors)
#   Downloading lovely_numpy-0.2.11-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from lovely-numpy>=0.2.9->lovely-tensors) (1.25.2)
# Requirement already satisfied: fastcore in /usr/local/lib/python3.10/dist-packages (from lovely-numpy>=0.2.9->lovely-tensors) (1.5.29)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from lovely-numpy>=0.2.9->lovely-tensors) (7.34.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from lovely-numpy>=0.2.9->lovely-tensors) (3.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->lovely-tensors) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->lovely-tensors) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->lovely-tensors) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->lovely-tensors) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->lovely-tensors) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->lovely-tensors) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->lovely-tensors) (2.1.0)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from fastcore->lovely-numpy>=0.2.9->lovely-tensors) (23.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastcore->lovely-numpy>=0.2.9->lovely-tensors) (23.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->lovely-numpy>=0.2.9->lovely-tensors) (67.7.2)
# Collecting jedi>=0.16 (from ipython->lovely-numpy>=0.2.9->lovely-tensors)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->lovely-numpy>=0.2.9->lovely-tensors) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->lovely-numpy>=0.2.9->lovely-tensors) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->lovely-numpy>=0.2.9->lovely-tensors) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->lovely-numpy>=0.2.9->lovely-tensors) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->lovely-numpy>=0.2.9->lovely-tensors) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->lovely-numpy>=0.2.9->lovely-tensors) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->lovely-numpy>=0.2.9->lovely-tensors) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->lovely-numpy>=0.2.9->lovely-tensors) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->lovely-tensors) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lovely-numpy>=0.2.9->lovely-tensors) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lovely-numpy>=0.2.9->lovely-tensors) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lovely-numpy>=0.2.9->lovely-tensors) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lovely-numpy>=0.2.9->lovely-tensors) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lovely-numpy>=0.2.9->lovely-tensors) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lovely-numpy>=0.2.9->lovely-tensors) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lovely-numpy>=0.2.9->lovely-tensors) (2.8.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->lovely-tensors) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->lovely-numpy>=0.2.9->lovely-tensors) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->lovely-numpy>=0.2.9->lovely-tensors) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->lovely-numpy>=0.2.9->lovely-tensors) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->lovely-numpy>=0.2.9->lovely-tensors) (1.16.0)
# Installing collected packages: jedi, lovely-numpy, lovely-tensors
# Successfully installed jedi-0.19.1 lovely-numpy-0.2.11 lovely-tensors-0.1.15

# %%
import os
import sys
import time
import math
import random
import itertools
from datetime import datetime
from typing import Mapping, Tuple, Sequence, List

import pandas as pd
import networkx as nx
import numpy as np
import scipy as sp

from tqdm.notebook import tqdm

import torch
import torch.nn.functional as F
from torch.nn import Embedding, Linear, ReLU, BatchNorm1d, LayerNorm, Module, ModuleList, Sequential
from torch.nn import TransformerEncoder, TransformerEncoderLayer, MultiheadAttention
from torch.optim import Adam

import torch_geometric
from torch_geometric.data import Data, Batch
from torch_geometric.loader import DataLoader
from torch_geometric.datasets import Planetoid

import torch_geometric.transforms as T
from torch_geometric.utils import remove_self_loops, dense_to_sparse, to_dense_batch, to_dense_adj

from torch_geometric.nn import GCNConv, GATConv

from torch_scatter import scatter, scatter_mean, scatter_max, scatter_sum

import lovely_tensors as lt
lt.monkey_patch()

import matplotlib.pyplot as plt
import seaborn as sns

# import warnings
# warnings.filterwarnings("ignore", category=RuntimeWarning)
# warnings.filterwarnings("ignore", category=UserWarning)
# warnings.filterwarnings("ignore", category=FutureWarning)

print("All imports succeeded.")
print("Python version {}".format(sys.version))
print("PyTorch version {}".format(torch.__version__))
print("PyG version {}".format(torch_geometric.__version__))
# Out:
# All imports succeeded.
# Python version 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# PyTorch version 2.1.0+cu121
# PyG version 2.5.0

# %%
# Set random seed for deterministic results

def seed(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed(0)
print("All seeds set.")
# Out:
# All seeds set.

# %%
# Download and load Cora dataset
dataset = 'Cora'
# transform = T.Compose([T.NormalizeFeatures(), T.GCNNorm(), T.ToSparseTensor()])
dataset = Planetoid('/tmp/Cora', dataset)
data = dataset[0]
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Done!

# %%
# adjacency matrices for Cora
A = to_dense_adj(data.edge_index, max_num_nodes = data.x.shape[0])[0]
A_tilde = A + torch.eye(A.shape[0])
D_tilde = torch.diag(torch.sum(A_tilde, axis=1))
D_tilde_inv_sqrt = torch.pow(D_tilde, -0.5)
D_tilde_inv_sqrt[torch.isinf(D_tilde_inv_sqrt)] = 0.0
A_tilde = A_tilde.to_sparse()
D_tilde_inv_sqrt = D_tilde_inv_sqrt.to_sparse()
adj_norm = torch.sparse.mm(torch.sparse.mm(D_tilde_inv_sqrt, A_tilde), D_tilde_inv_sqrt) # degree-normalised adjacency
L = torch.eye(adj_norm.shape[0]) - adj_norm  # graph laplacian

# # Eigenvectors with numpy
# EigVal, EigVec = np.linalg.eig(L)
# idx = EigVal.argsort() # sort in increasing order
# EigVal, EigVec = EigVal[idx], np.real(EigVec[:,idx])

plt.figure(figsize=(8, 8))
sns.heatmap(adj_norm.to_dense().numpy(), cmap='viridis', square=True)
plt.title('Adjacency Matrix Heatmap')
plt.show()
# Out:
# <ipython-input-5-449309cf93f5>:9: UserWarning: Sparse CSR tensor support is in beta state. If you miss a functionality in the sparse tensor support, please submit a feature request to https://github.com/pytorch/pytorch/issues. (Triggered internally at ../aten/src/ATen/SparseCsrTensorImpl.cpp:53.)
#   adj_norm = torch.sparse.mm(torch.sparse.mm(D_tilde_inv_sqrt, A_tilde), D_tilde_inv_sqrt) # degree-normalised adjacency

# %%
# PyG example code: https://github.com/pyg-team/pytorch_geometric/blob/master/examples/gcn2_cora.py

class GNNModel(Module):

    def __init__(
            self,
            in_dim: int = dataset.num_features,
            hidden_dim: int = 128,
            num_heads: int = 1,
            num_layers: int = 3,
            out_dim: int = dataset.num_classes,
            dropout: float = 0.5,
        ):
        super().__init__()

        self.lin_in = Linear(in_dim, hidden_dim)
        self.lin_out = Linear(hidden_dim, out_dim)

        self.layers = ModuleList()
        for layer in range(num_layers):
            self.layers.append(
                # GCNConv(hidden_dim, hidden_dim)
                GATConv(hidden_dim, hidden_dim // num_heads, num_heads)
            )
        self.dropout = dropout

    def forward(self, x, edge_index):

        x = self.lin_in(x)

        for layer in self.layers:
            # conv -> activation ->  dropout -> residual
            x_in = x
            x = layer(x, edge_index)
            x = F.relu(x)
            x = F.dropout(x, self.dropout, training=self.training)
            x = x_in + x

        x = self.lin_out(x)

        return x.log_softmax(dim=-1)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = GNNModel().to(device)

data = data.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)


def train():
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index)
    loss = F.nll_loss(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    return float(loss)


@torch.no_grad()
def test():
    model.eval()
    pred, accs = model(data.x, data.edge_index).argmax(dim=-1), []
    for _, mask in data('train_mask', 'val_mask', 'test_mask'):
        accs.append(int((pred[mask] == data.y[mask]).sum()) / int(mask.sum()))
    return accs


best_val_acc = test_acc = 0
times = []
for epoch in range(1, 100):
    start = time.time()
    loss = train()
    train_acc, val_acc, tmp_test_acc = test()
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        test_acc = tmp_test_acc
    print(f'Epoch: {epoch:04d}, Loss: {loss:.4f} Train: {train_acc:.4f}, '
          f'Val: {val_acc:.4f}, Test: {tmp_test_acc:.4f}, '
          f'Final Test: {test_acc:.4f}')
    times.append(time.time() - start)
print(f"Median time per epoch: {torch.tensor(times).median():.4f}s")
# Out:
# Epoch: 0001, Loss: 1.9564 Train: 0.4143, Val: 0.1540, Test: 0.1650, Final Test: 0.1650
# Epoch: 0002, Loss: 1.8827 Train: 0.7071, Val: 0.2200, Test: 0.2460, Final Test: 0.2460
# Epoch: 0003, Loss: 1.8154 Train: 0.8929, Val: 0.2880, Test: 0.3280, Final Test: 0.3280
# Epoch: 0004, Loss: 1.7430 Train: 0.9214, Val: 0.3480, Test: 0.4090, Final Test: 0.4090
# Epoch: 0005, Loss: 1.6689 Train: 0.9571, Val: 0.4020, Test: 0.4590, Final Test: 0.4590
# Epoch: 0006, Loss: 1.5866 Train: 0.9857, Val: 0.4600, Test: 0.4970, Final Test: 0.4970
# Epoch: 0007, Loss: 1.5064 Train: 0.9929, Val: 0.4960, Test: 0.5360, Final Test: 0.5360
# Epoch: 0008, Loss: 1.4049 Train: 0.9929, Val: 0.5420, Test: 0.5630, Final Test: 0.5630
# Epoch: 0009, Loss: 1.3038 Train: 0.9929, Val: 0.5700, Test: 0.5910, Final Test: 0.5910
# Epoch: 0010, Loss: 1.2217 Train: 0.9929, Val: 0.6120, Test: 0.6130, Final Test: 0.6130
# Epoch: 0011, Loss: 1.0937 Train: 0.9929, Val: 0.6320, Test: 0.6360, Final Test: 0.6360
# Epoch: 0012, Loss: 0.9883 Train: 0.9929, Val: 0.6520, Test: 0.6480, Final Test: 0.6480
# Epoch: 0013, Loss: 0.8834 Train: 0.9929, Val: 0.6700, Test: 0.6600, Final Test: 0.6600
# Epoch: 0014, Loss: 0.7792 Train: 0.9929, Val: 0.6760, Test: 0.6750, Final Test: 0.6750
# Epoch: 0015, Loss: 0.6780 Train: 1.0000, Val: 0.6920, Test: 0.6910, Final Test: 0.6910
# Epoch: 0016, Loss: 0.5605 Train: 1.0000, Val: 0.7040, Test: 0.7120, Final Test: 0.7120
# Epoch: 0017, Loss: 0.4810 Train: 1.0000, Val: 0.7180, Test: 0.7220, Final Test: 0.7220
# Epoch: 0018, Loss: 0.3937 Train: 1.0000, Val: 0.7340, Test: 0.7340, Final Test: 0.7340
# Epoch: 0019, Loss: 0.3100 Train: 1.0000, Val: 0.7520, Test: 0.7470, Final Test: 0.7470
# Epoch: 0020, Loss: 0.2524 Train: 1.0000, Val: 0.7540, Test: 0.7580, Final Test: 0.7580
# Epoch: 0021, Loss: 0.2070 Train: 1.0000, Val: 0.7660, Test: 0.7600, Final Test: 0.7600
# Epoch: 0022, Loss: 0.1590 Train: 1.0000, Val: 0.7660, Test: 0.7670, Final Test: 0.7600
# Epoch: 0023, Loss: 0.1243 Train: 1.0000, Val: 0.7720, Test: 0.7700, Final Test: 0.7700
# Epoch: 0024, Loss: 0.1007 Train: 1.0000, Val: 0.7700, Test: 0.7730, Final Test: 0.7700
# Epoch: 0025, Loss: 0.0853 Train: 1.0000, Val: 0.7660, Test: 0.7720, Final Test: 0.7700
# Epoch: 0026, Loss: 0.0620 Train: 1.0000, Val: 0.7720, Test: 0.7780, Final Test: 0.7700
# Epoch: 0027, Loss: 0.0466 Train: 1.0000, Val: 0.7720, Test: 0.7780, Final Test: 0.7700
# Epoch: 0028, Loss: 0.0412 Train: 1.0000, Val: 0.7760, Test: 0.7760, Final Test: 0.7760
# Epoch: 0029, Loss: 0.0286 Train: 1.0000, Val: 0.7700, Test: 0.7790, Final Test: 0.7760
# Epoch: 0030, Loss: 0.0206 Train: 1.0000, Val: 0.7640, Test: 0.7780, Final Test: 0.7760
# Epoch: 0031, Loss: 0.0159 Train: 1.0000, Val: 0.7600, Test: 0.7760, Final Test: 0.7760
# Epoch: 0032, Loss: 0.0126 Train: 1.0000, Val: 0.7600, Test: 0.7740, Final Test: 0.7760
# Epoch: 0033, Loss: 0.0136 Train: 1.0000, Val: 0.7580, Test: 0.7710, Final Test: 0.7760
# Epoch: 0034, Loss: 0.0106 Train: 1.0000, Val: 0.7540, Test: 0.7720, Final Test: 0.7760
# Epoch: 0035, Loss: 0.0084 Train: 1.0000, Val: 0.7540, Test: 0.7740, Final Test: 0.7760
# Epoch: 0036, Loss: 0.0053 Train: 1.0000, Val: 0.7460, Test: 0.7770, Final Test: 0.7760
# Epoch: 0037, Loss: 0.0035 Train: 1.0000, Val: 0.7440, Test: 0.7780, Final Test: 0.7760
# Epoch: 0038, Loss: 0.0041 Train: 1.0000, Val: 0.7400, Test: 0.7810, Final Test: 0.7760
# Epoch: 0039, Loss: 0.0043 Train: 1.0000, Val: 0.7400, Test: 0.7770, Final Test: 0.7760
# Epoch: 0040, Loss: 0.0037 Train: 1.0000, Val: 0.7380, Test: 0.7750, Final Test: 0.7760
# Epoch: 0041, Loss: 0.0025 Train: 1.0000, Val: 0.7400, Test: 0.7740, Final Test: 0.7760
# Epoch: 0042, Loss: 0.0052 Train: 1.0000, Val: 0.7400, Test: 0.7740, Final Test: 0.7760
# Epoch: 0043, Loss: 0.0031 Train: 1.0000, Val: 0.7400, Test: 0.7750, Final Test: 0.7760
# Epoch: 0044, Loss: 0.0024 Train: 1.0000, Val: 0.7460, Test: 0.7730, Final Test: 0.7760
# Epoch: 0045, Loss: 0.0020 Train: 1.0000, Val: 0.7460, Test: 0.7700, Final Test: 0.7760
# Epoch: 0046, Loss: 0.0020 Train: 1.0000, Val: 0.7440, Test: 0.7680, Final Test: 0.7760
# Epoch: 0047, Loss: 0.0018 Train: 1.0000, Val: 0.7420, Test: 0.7690, Final Test: 0.7760
# Epoch: 0048, Loss: 0.0044 Train: 1.0000, Val: 0.7420, Test: 0.7690, Final Test: 0.7760
# Epoch: 0049, Loss: 0.0024 Train: 1.0000, Val: 0.7380, Test: 0.7690, Final Test: 0.7760
# Epoch: 0050, Loss: 0.0024 Train: 1.0000, Val: 0.7380, Test: 0.7670, Final Test: 0.7760
# Epoch: 0051, Loss: 0.0007 Train: 1.0000, Val: 0.7360, Test: 0.7670, Final Test: 0.7760
# Epoch: 0052, Loss: 0.0014 Train: 1.0000, Val: 0.7380, Test: 0.7660, Final Test: 0.7760
# Epoch: 0053, Loss: 0.0017 Train: 1.0000, Val: 0.7380, Test: 0.7640, Final Test: 0.7760
# Epoch: 0054, Loss: 0.0017 Train: 1.0000, Val: 0.7400, Test: 0.7640, Final Test: 0.7760
# Epoch: 0055, Loss: 0.0006 Train: 1.0000, Val: 0.7400, Test: 0.7650, Final Test: 0.7760
# Epoch: 0056, Loss: 0.0009 Train: 1.0000, Val: 0.7420, Test: 0.7660, Final Test: 0.7760
# Epoch: 0057, Loss: 0.0007 Train: 1.0000, Val: 0.7420, Test: 0.7680, Final Test: 0.7760
# Epoch: 0058, Loss: 0.0010 Train: 1.0000, Val: 0.7440, Test: 0.7660, Final Test: 0.7760
# Epoch: 0059, Loss: 0.0015 Train: 1.0000, Val: 0.7440, Test: 0.7660, Final Test: 0.7760
# Epoch: 0060, Loss: 0.0008 Train: 1.0000, Val: 0.7440, Test: 0.7660, Final Test: 0.7760
# Epoch: 0061, Loss: 0.0008 Train: 1.0000, Val: 0.7440, Test: 0.7630, Final Test: 0.7760
# Epoch: 0062, Loss: 0.0006 Train: 1.0000, Val: 0.7440, Test: 0.7630, Final Test: 0.7760
# Epoch: 0063, Loss: 0.0006 Train: 1.0000, Val: 0.7440, Test: 0.7630, Final Test: 0.7760
# Epoch: 0064, Loss: 0.0006 Train: 1.0000, Val: 0.7460, Test: 0.7620, Final Test: 0.7760
# Epoch: 0065, Loss: 0.0010 Train: 1.0000, Val: 0.7460, Test: 0.7620, Final Test: 0.7760
# Epoch: 0066, Loss: 0.0007 Train: 1.0000, Val: 0.7440, Test: 0.7640, Final Test: 0.7760
# Epoch: 0067, Loss: 0.0014 Train: 1.0000, Val: 0.7460, Test: 0.7670, Final Test: 0.7760
# Epoch: 0068, Loss: 0.0008 Train: 1.0000, Val: 0.7480, Test: 0.7700, Final Test: 0.7760
# Epoch: 0069, Loss: 0.0008 Train: 1.0000, Val: 0.7460, Test: 0.7700, Final Test: 0.7760
# Epoch: 0070, Loss: 0.0005 Train: 1.0000, Val: 0.7440, Test: 0.7700, Final Test: 0.7760
# Epoch: 0071, Loss: 0.0003 Train: 1.0000, Val: 0.7460, Test: 0.7700, Final Test: 0.7760
# Epoch: 0072, Loss: 0.0013 Train: 1.0000, Val: 0.7460, Test: 0.7700, Final Test: 0.7760
# Epoch: 0073, Loss: 0.0010 Train: 1.0000, Val: 0.7440, Test: 0.7710, Final Test: 0.7760
# Epoch: 0074, Loss: 0.0008 Train: 1.0000, Val: 0.7420, Test: 0.7710, Final Test: 0.7760
# Epoch: 0075, Loss: 0.0005 Train: 1.0000, Val: 0.7420, Test: 0.7720, Final Test: 0.7760
# Epoch: 0076, Loss: 0.0007 Train: 1.0000, Val: 0.7440, Test: 0.7740, Final Test: 0.7760
# Epoch: 0077, Loss: 0.0007 Train: 1.0000, Val: 0.7440, Test: 0.7730, Final Test: 0.7760
# Epoch: 0078, Loss: 0.0004 Train: 1.0000, Val: 0.7420, Test: 0.7730, Final Test: 0.7760
# Epoch: 0079, Loss: 0.0006 Train: 1.0000, Val: 0.7440, Test: 0.7720, Final Test: 0.7760
# Epoch: 0080, Loss: 0.0005 Train: 1.0000, Val: 0.7440, Test: 0.7710, Final Test: 0.7760
# Epoch: 0081, Loss: 0.0008 Train: 1.0000, Val: 0.7420, Test: 0.7700, Final Test: 0.7760
# Epoch: 0082, Loss: 0.0005 Train: 1.0000, Val: 0.7420, Test: 0.7730, Final Test: 0.7760
# Epoch: 0083, Loss: 0.0011 Train: 1.0000, Val: 0.7420, Test: 0.7720, Final Test: 0.7760
# Epoch: 0084, Loss: 0.0002 Train: 1.0000, Val: 0.7420, Test: 0.7710, Final Test: 0.7760
# Epoch: 0085, Loss: 0.0004 Train: 1.0000, Val: 0.7400, Test: 0.7710, Final Test: 0.7760
# Epoch: 0086, Loss: 0.0005 Train: 1.0000, Val: 0.7400, Test: 0.7700, Final Test: 0.7760
# Epoch: 0087, Loss: 0.0004 Train: 1.0000, Val: 0.7400, Test: 0.7700, Final Test: 0.7760
# Epoch: 0088, Loss: 0.0003 Train: 1.0000, Val: 0.7400, Test: 0.7700, Final Test: 0.7760
# Epoch: 0089, Loss: 0.0004 Train: 1.0000, Val: 0.7400, Test: 0.7700, Final Test: 0.7760
# Epoch: 0090, Loss: 0.0003 Train: 1.0000, Val: 0.7400, Test: 0.7700, Final Test: 0.7760
# Epoch: 0091, Loss: 0.0004 Train: 1.0000, Val: 0.7400, Test: 0.7700, Final Test: 0.7760
# Epoch: 0092, Loss: 0.0002 Train: 1.0000, Val: 0.7400, Test: 0.7710, Final Test: 0.7760
# Epoch: 0093, Loss: 0.0004 Train: 1.0000, Val: 0.7400, Test: 0.7720, Final Test: 0.7760
# Epoch: 0094, Loss: 0.0003 Train: 1.0000, Val: 0.7400, Test: 0.7720, Final Test: 0.7760
# Epoch: 0095, Loss: 0.0003 Train: 1.0000, Val: 0.7400, Test: 0.7710, Final Test: 0.7760
# Epoch: 0096, Loss: 0.0005 Train: 1.0000, Val: 0.7400, Test: 0.7710, Final Test: 0.7760
# Epoch: 0097, Loss: 0.0002 Train: 1.0000, Val: 0.7400, Test: 0.7720, Final Test: 0.7760
# Epoch: 0098, Loss: 0.0003 Train: 1.0000, Val: 0.7400, Test: 0.7730, Final Test: 0.7760
# Epoch: 0099, Loss: 0.0005 Train: 1.0000, Val: 0.7400, Test: 0.7720, Final Test: 0.7760
# Median time per epoch: 0.0196s

# %%
class SparseGraphTransformerModel(Module):

    def __init__(
            self,
            in_dim: int = dataset.num_features,
            hidden_dim: int = 128,
            num_heads: int = 4,
            num_layers: int = 3,
            out_dim: int = dataset.num_classes,
            dropout: float = 0.5,
        ):
        super().__init__()

        self.lin_in = Linear(in_dim, hidden_dim)
        self.lin_out = Linear(hidden_dim, out_dim)

        self.layers = ModuleList()
        for layer in range(num_layers):
            self.layers.append(
                # TransformerEncoderLayer(
                #     d_model = hidden_dim,
                #     nhead = num_heads,
                #     dim_feedforward = hidden_dim * 2,
                #     dropout = dropout,
                # )
                MultiheadAttention(
                    embed_dim = hidden_dim,
                    num_heads = num_heads,
                    dropout = dropout
                )
            )
        # self.encoder = TransformerEncoder(
        #     TransformerEncoderLayer(
        #         d_model = hidden_dim,
        #         nhead = num_heads,
        #         dim_feedforward = hidden_dim * 2,
        #         dropout = dropout,
        #     ),
        #     num_layers
        # )

        self.dropout = dropout

    def forward(self, x, dense_adj):

        x = self.lin_in(x)

        # TransformerEncoder
        # x = self.encoder(x, mask = ~dense_adj.bool())

        self.attn_weights_list = []

        for layer in self.layers:
            # # TransformerEncoderLayer
            # # boolean mask enforces graph structure
            # x = layer(x, src_mask = ~dense_adj.bool())

            # MHSA layer
            # boolean mask enforces graph structure
            x_in = x
            x, attn_weights = layer(
                x, x, x,
                attn_mask = ~dense_adj.bool(),
                average_attn_weights = False
            )
            x = F.relu(x)
            x = F.dropout(x, self.dropout, training=self.training)
            x = x_in + x

            self.attn_weights_list.append(attn_weights)

        x = self.lin_out(x)

        return x.log_softmax(dim=-1)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = SparseGraphTransformerModel().to(device)

data.dense_adj = to_dense_adj(data.edge_index, max_num_nodes = data.x.shape[0])[0]
data = data.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)


def train():
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.dense_adj)
    loss = F.nll_loss(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    return float(loss)


@torch.no_grad()
def test():
    model.eval()
    pred, accs = model(data.x, data.dense_adj).argmax(dim=-1), []
    for _, mask in data('train_mask', 'val_mask', 'test_mask'):
        accs.append(int((pred[mask] == data.y[mask]).sum()) / int(mask.sum()))
    return accs


best_val_acc = test_acc = 0
times = []
for epoch in range(1, 100):
    start = time.time()
    loss = train()
    train_acc, val_acc, tmp_test_acc = test()
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        test_acc = tmp_test_acc
    print(f'Epoch: {epoch:04d}, Loss: {loss:.4f} Train: {train_acc:.4f}, '
          f'Val: {val_acc:.4f}, Test: {tmp_test_acc:.4f}, '
          f'Final Test: {test_acc:.4f}')
    times.append(time.time() - start)
print(f"Median time per epoch: {torch.tensor(times).median():.4f}s")
# Out:
# Epoch: 0001, Loss: 1.9477 Train: 0.3857, Val: 0.1680, Test: 0.1670, Final Test: 0.1670
# Epoch: 0002, Loss: 1.8815 Train: 0.7429, Val: 0.2280, Test: 0.2230, Final Test: 0.2230
# Epoch: 0003, Loss: 1.8286 Train: 0.9429, Val: 0.3080, Test: 0.3240, Final Test: 0.3240
# Epoch: 0004, Loss: 1.7692 Train: 0.9786, Val: 0.3980, Test: 0.4210, Final Test: 0.4210
# Epoch: 0005, Loss: 1.7096 Train: 0.9857, Val: 0.4620, Test: 0.4980, Final Test: 0.4980
# Epoch: 0006, Loss: 1.6444 Train: 1.0000, Val: 0.5200, Test: 0.5680, Final Test: 0.5680
# Epoch: 0007, Loss: 1.5760 Train: 1.0000, Val: 0.5840, Test: 0.6160, Final Test: 0.6160
# Epoch: 0008, Loss: 1.5053 Train: 1.0000, Val: 0.6160, Test: 0.6430, Final Test: 0.6430
# Epoch: 0009, Loss: 1.4244 Train: 1.0000, Val: 0.6380, Test: 0.6720, Final Test: 0.6720
# Epoch: 0010, Loss: 1.3244 Train: 1.0000, Val: 0.6620, Test: 0.6910, Final Test: 0.6910
# Epoch: 0011, Loss: 1.2344 Train: 1.0000, Val: 0.6780, Test: 0.7140, Final Test: 0.7140
# Epoch: 0012, Loss: 1.1297 Train: 1.0000, Val: 0.6940, Test: 0.7310, Final Test: 0.7310
# Epoch: 0013, Loss: 1.0234 Train: 1.0000, Val: 0.7140, Test: 0.7490, Final Test: 0.7490
# Epoch: 0014, Loss: 0.9248 Train: 0.9929, Val: 0.7340, Test: 0.7590, Final Test: 0.7590
# Epoch: 0015, Loss: 0.7824 Train: 0.9929, Val: 0.7480, Test: 0.7680, Final Test: 0.7680
# Epoch: 0016, Loss: 0.6863 Train: 0.9929, Val: 0.7600, Test: 0.7740, Final Test: 0.7740
# Epoch: 0017, Loss: 0.5586 Train: 0.9929, Val: 0.7640, Test: 0.7810, Final Test: 0.7810
# Epoch: 0018, Loss: 0.4765 Train: 0.9929, Val: 0.7660, Test: 0.7850, Final Test: 0.7850
# Epoch: 0019, Loss: 0.3696 Train: 0.9929, Val: 0.7640, Test: 0.7950, Final Test: 0.7850
# Epoch: 0020, Loss: 0.2948 Train: 0.9929, Val: 0.7700, Test: 0.7930, Final Test: 0.7930
# Epoch: 0021, Loss: 0.2329 Train: 0.9929, Val: 0.7740, Test: 0.7900, Final Test: 0.7900
# Epoch: 0022, Loss: 0.1646 Train: 0.9929, Val: 0.7800, Test: 0.7900, Final Test: 0.7900
# Epoch: 0023, Loss: 0.1184 Train: 1.0000, Val: 0.7800, Test: 0.7970, Final Test: 0.7900
# Epoch: 0024, Loss: 0.0980 Train: 1.0000, Val: 0.7840, Test: 0.7950, Final Test: 0.7950
# Epoch: 0025, Loss: 0.0718 Train: 1.0000, Val: 0.7860, Test: 0.7960, Final Test: 0.7960
# Epoch: 0026, Loss: 0.0439 Train: 1.0000, Val: 0.7780, Test: 0.8050, Final Test: 0.7960
# Epoch: 0027, Loss: 0.0396 Train: 1.0000, Val: 0.7780, Test: 0.8060, Final Test: 0.7960
# Epoch: 0028, Loss: 0.0337 Train: 1.0000, Val: 0.7840, Test: 0.8070, Final Test: 0.7960
# Epoch: 0029, Loss: 0.0186 Train: 1.0000, Val: 0.7840, Test: 0.8060, Final Test: 0.7960
# Epoch: 0030, Loss: 0.0197 Train: 1.0000, Val: 0.7880, Test: 0.7970, Final Test: 0.7970
# Epoch: 0031, Loss: 0.0167 Train: 1.0000, Val: 0.7820, Test: 0.7850, Final Test: 0.7970
# Epoch: 0032, Loss: 0.0104 Train: 1.0000, Val: 0.7780, Test: 0.7840, Final Test: 0.7970
# Epoch: 0033, Loss: 0.0114 Train: 1.0000, Val: 0.7760, Test: 0.7850, Final Test: 0.7970
# Epoch: 0034, Loss: 0.0065 Train: 1.0000, Val: 0.7760, Test: 0.7850, Final Test: 0.7970
# Epoch: 0035, Loss: 0.0058 Train: 1.0000, Val: 0.7740, Test: 0.7830, Final Test: 0.7970
# Epoch: 0036, Loss: 0.0044 Train: 1.0000, Val: 0.7760, Test: 0.7850, Final Test: 0.7970
# Epoch: 0037, Loss: 0.0032 Train: 1.0000, Val: 0.7780, Test: 0.7860, Final Test: 0.7970
# Epoch: 0038, Loss: 0.0043 Train: 1.0000, Val: 0.7820, Test: 0.7900, Final Test: 0.7970
# Epoch: 0039, Loss: 0.0022 Train: 1.0000, Val: 0.7820, Test: 0.7950, Final Test: 0.7970
# Epoch: 0040, Loss: 0.0086 Train: 1.0000, Val: 0.7880, Test: 0.7940, Final Test: 0.7970
# Epoch: 0041, Loss: 0.0007 Train: 1.0000, Val: 0.7860, Test: 0.7990, Final Test: 0.7970
# Epoch: 0042, Loss: 0.0046 Train: 1.0000, Val: 0.7840, Test: 0.7980, Final Test: 0.7970
# Epoch: 0043, Loss: 0.0284 Train: 1.0000, Val: 0.7880, Test: 0.8010, Final Test: 0.7970
# Epoch: 0044, Loss: 0.0052 Train: 1.0000, Val: 0.7840, Test: 0.7930, Final Test: 0.7970
# Epoch: 0045, Loss: 0.0074 Train: 1.0000, Val: 0.7800, Test: 0.7820, Final Test: 0.7970
# Epoch: 0046, Loss: 0.0148 Train: 1.0000, Val: 0.7800, Test: 0.7790, Final Test: 0.7970
# Epoch: 0047, Loss: 0.0123 Train: 1.0000, Val: 0.7700, Test: 0.7830, Final Test: 0.7970
# Epoch: 0048, Loss: 0.0114 Train: 1.0000, Val: 0.7500, Test: 0.7700, Final Test: 0.7970
# Epoch: 0049, Loss: 0.0012 Train: 1.0000, Val: 0.7500, Test: 0.7620, Final Test: 0.7970
# Epoch: 0050, Loss: 0.0083 Train: 0.9929, Val: 0.7340, Test: 0.7580, Final Test: 0.7970
# Epoch: 0051, Loss: 0.0133 Train: 0.9929, Val: 0.7340, Test: 0.7540, Final Test: 0.7970
# Epoch: 0052, Loss: 0.0030 Train: 1.0000, Val: 0.7340, Test: 0.7530, Final Test: 0.7970
# Epoch: 0053, Loss: 0.0010 Train: 1.0000, Val: 0.7420, Test: 0.7540, Final Test: 0.7970
# Epoch: 0054, Loss: 0.0267 Train: 1.0000, Val: 0.7420, Test: 0.7510, Final Test: 0.7970
# Epoch: 0055, Loss: 0.0031 Train: 1.0000, Val: 0.7500, Test: 0.7510, Final Test: 0.7970
# Epoch: 0056, Loss: 0.0022 Train: 1.0000, Val: 0.7500, Test: 0.7490, Final Test: 0.7970
# Epoch: 0057, Loss: 0.0060 Train: 1.0000, Val: 0.7500, Test: 0.7540, Final Test: 0.7970
# Epoch: 0058, Loss: 0.0173 Train: 1.0000, Val: 0.7540, Test: 0.7540, Final Test: 0.7970
# Epoch: 0059, Loss: 0.0078 Train: 1.0000, Val: 0.7480, Test: 0.7560, Final Test: 0.7970
# Epoch: 0060, Loss: 0.0036 Train: 1.0000, Val: 0.7440, Test: 0.7600, Final Test: 0.7970
# Epoch: 0061, Loss: 0.0019 Train: 1.0000, Val: 0.7460, Test: 0.7590, Final Test: 0.7970
# Epoch: 0062, Loss: 0.0016 Train: 1.0000, Val: 0.7400, Test: 0.7570, Final Test: 0.7970
# Epoch: 0063, Loss: 0.0009 Train: 1.0000, Val: 0.7340, Test: 0.7590, Final Test: 0.7970
# Epoch: 0064, Loss: 0.0030 Train: 1.0000, Val: 0.7340, Test: 0.7570, Final Test: 0.7970
# Epoch: 0065, Loss: 0.0044 Train: 1.0000, Val: 0.7340, Test: 0.7570, Final Test: 0.7970
# Epoch: 0066, Loss: 0.0023 Train: 1.0000, Val: 0.7340, Test: 0.7550, Final Test: 0.7970
# Epoch: 0067, Loss: 0.0015 Train: 1.0000, Val: 0.7360, Test: 0.7580, Final Test: 0.7970
# Epoch: 0068, Loss: 0.0010 Train: 1.0000, Val: 0.7420, Test: 0.7600, Final Test: 0.7970
# Epoch: 0069, Loss: 0.0043 Train: 1.0000, Val: 0.7380, Test: 0.7640, Final Test: 0.7970
# Epoch: 0070, Loss: 0.0009 Train: 1.0000, Val: 0.7380, Test: 0.7660, Final Test: 0.7970
# Epoch: 0071, Loss: 0.0014 Train: 1.0000, Val: 0.7400, Test: 0.7640, Final Test: 0.7970
# Epoch: 0072, Loss: 0.0008 Train: 1.0000, Val: 0.7440, Test: 0.7650, Final Test: 0.7970
# Epoch: 0073, Loss: 0.0032 Train: 1.0000, Val: 0.7420, Test: 0.7680, Final Test: 0.7970
# Epoch: 0074, Loss: 0.0007 Train: 1.0000, Val: 0.7380, Test: 0.7660, Final Test: 0.7970
# Epoch: 0075, Loss: 0.0016 Train: 1.0000, Val: 0.7360, Test: 0.7660, Final Test: 0.7970
# Epoch: 0076, Loss: 0.0009 Train: 1.0000, Val: 0.7300, Test: 0.7650, Final Test: 0.7970
# Epoch: 0077, Loss: 0.0007 Train: 1.0000, Val: 0.7300, Test: 0.7660, Final Test: 0.7970
# Epoch: 0078, Loss: 0.0021 Train: 1.0000, Val: 0.7300, Test: 0.7670, Final Test: 0.7970
# Epoch: 0079, Loss: 0.0010 Train: 1.0000, Val: 0.7300, Test: 0.7670, Final Test: 0.7970
# Epoch: 0080, Loss: 0.0005 Train: 1.0000, Val: 0.7300, Test: 0.7690, Final Test: 0.7970
# Epoch: 0081, Loss: 0.0016 Train: 1.0000, Val: 0.7340, Test: 0.7680, Final Test: 0.7970
# Epoch: 0082, Loss: 0.0013 Train: 1.0000, Val: 0.7360, Test: 0.7670, Final Test: 0.7970
# Epoch: 0083, Loss: 0.0011 Train: 1.0000, Val: 0.7440, Test: 0.7670, Final Test: 0.7970
# Epoch: 0084, Loss: 0.0014 Train: 1.0000, Val: 0.7480, Test: 0.7660, Final Test: 0.7970
# Epoch: 0085, Loss: 0.0005 Train: 1.0000, Val: 0.7480, Test: 0.7650, Final Test: 0.7970
# Epoch: 0086, Loss: 0.0004 Train: 1.0000, Val: 0.7500, Test: 0.7650, Final Test: 0.7970
# Epoch: 0087, Loss: 0.0014 Train: 1.0000, Val: 0.7480, Test: 0.7650, Final Test: 0.7970
# Epoch: 0088, Loss: 0.0005 Train: 1.0000, Val: 0.7480, Test: 0.7650, Final Test: 0.7970
# Epoch: 0089, Loss: 0.0022 Train: 1.0000, Val: 0.7480, Test: 0.7640, Final Test: 0.7970
# Epoch: 0090, Loss: 0.0012 Train: 1.0000, Val: 0.7500, Test: 0.7640, Final Test: 0.7970
# Epoch: 0091, Loss: 0.0004 Train: 1.0000, Val: 0.7520, Test: 0.7640, Final Test: 0.7970
# Epoch: 0092, Loss: 0.0005 Train: 1.0000, Val: 0.7560, Test: 0.7640, Final Test: 0.7970
# Epoch: 0093, Loss: 0.0005 Train: 1.0000, Val: 0.7540, Test: 0.7660, Final Test: 0.7970
# Epoch: 0094, Loss: 0.0009 Train: 1.0000, Val: 0.7540, Test: 0.7660, Final Test: 0.7970
# Epoch: 0095, Loss: 0.0007 Train: 1.0000, Val: 0.7520, Test: 0.7670, Final Test: 0.7970
# Epoch: 0096, Loss: 0.0035 Train: 1.0000, Val: 0.7520, Test: 0.7670, Final Test: 0.7970
# Epoch: 0097, Loss: 0.0002 Train: 1.0000, Val: 0.7520, Test: 0.7670, Final Test: 0.7970
# Epoch: 0098, Loss: 0.0007 Train: 1.0000, Val: 0.7520, Test: 0.7670, Final Test: 0.7970
# Epoch: 0099, Loss: 0.0035 Train: 1.0000, Val: 0.7520, Test: 0.7680, Final Test: 0.7970
# Median time per epoch: 0.0658s

# %%
num_layers = len(model.attn_weights_list)
num_heads = model.attn_weights_list[0].shape[0]

fig, axes = plt.subplots(num_layers, num_heads, figsize=(num_heads * 4, num_layers * 4))

for layer_idx in range(num_layers):
    for head_idx in range(num_heads):
        ax = axes[layer_idx, head_idx]

        # Extract the attention heatmap for the current layer and head
        attn_heatmap = model.attn_weights_list[layer_idx][head_idx, :, :].cpu().numpy()

        # Plot the heatmap on the current subplot
        sns.heatmap(attn_heatmap, cmap='viridis', square=True, ax=ax)

        ax.set_title(f'Layer {layer_idx + 1}, Head {head_idx + 1}')
        ax.axis('off')

plt.suptitle('Attention Heatmaps', y=1.02)
plt.tight_layout()
plt.show()

# %%
def get_shortest_path_matrix(adjacency_matrix):
    # Convert the adjacency matrix to a NetworkX graph
    graph = nx.from_numpy_array(adjacency_matrix.cpu().numpy(), create_using=nx.DiGraph)
    # Compute the shortest path matrix using Floyd-Warshall algorithm in NetworkX
    shortest_path_matrix = nx.floyd_warshall_numpy(graph)
    # Convert numpy array back to torch tensor
    shortest_path_matrix = torch.tensor(shortest_path_matrix).float()
    return shortest_path_matrix

dense_adj = to_dense_adj(data.edge_index, max_num_nodes = data.x.shape[0])[0]
dense_shortest_path_matrix = get_shortest_path_matrix(dense_adj)  # takes about 1-2 mins

# %%
class DenseGraphTransformerModel(Module):

    def __init__(
            self,
            in_dim: int = dataset.num_features,
            pos_enc_dim: int = 16,
            hidden_dim: int = 128,
            num_heads: int = 4,
            num_layers: int = 3,
            out_dim: int = dataset.num_classes,
            dropout: float = 0.5,
        ):
        super().__init__()

        self.lin_in = Linear(in_dim, hidden_dim)
        self.lin_pos_enc = Linear(pos_enc_dim, hidden_dim)
        self.lin_out = Linear(hidden_dim, out_dim)

        self.layers = ModuleList()
        for layer in range(num_layers):
            self.layers.append(
                # TransformerEncoderLayer(
                #     d_model = hidden_dim,
                #     nhead = num_heads,
                #     dim_feedforward = hidden_dim * 2,
                #     dropout = dropout,
                # )
                MultiheadAttention(
                    embed_dim = hidden_dim,
                    num_heads = num_heads,
                    dropout = dropout
                )
            )
        # self.encoder = TransformerEncoder(
        #     TransformerEncoderLayer(
        #         d_model = hidden_dim,
        #         nhead = num_heads,
        #         dim_feedforward = hidden_dim * 2,
        #         dropout = dropout,
        #     ),
        #     num_layers
        # )

        self.attn_bias_scale = torch.nn.Parameter(torch.tensor([10.0]))  # controls how much we initially bias our model to nearby nodes
        self.dropout = dropout

    def forward(self, x, pos_enc, dense_sp_matrix):

        # x = self.lin_in(x) + self.lin_pos_enc(pos_enc)
        x = self.lin_in(x)  # no node positional encoding

        # attention bias
        # [i, j] -> inverse of shortest path distance b/w node i and j
        # diagonals -> self connection, set to 0
        # disconnected nodes -> -1
        attn_bias = self.attn_bias_scale * torch.nan_to_num(
            (1 / (torch.nan_to_num(dense_sp_matrix, nan=-1, posinf=-1, neginf=-1))),
            nan=0, posinf=0, neginf=0
        )

        # TransformerEncoder
        # x = self.encoder(x, mask = ~dense_adj.bool())

        for layer in self.layers:
            # # TransformerEncoderLayer
            # # float mask adds learnable additive attention bias
            # x = layer(x, src_mask = dense_adj.float())

            # MHSA layer
            # float mask adds learnable additive attention bias
            x_in = x
            x = layer(x, x, x, attn_mask = attn_bias)[0]
            x = F.relu(x)
            x = F.dropout(x, self.dropout, training=self.training)
            x = x_in + x

        x = self.lin_out(x)

        return x.log_softmax(dim=-1)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = DenseGraphTransformerModel().to(device)

# data = T.AddLaplacianEigenvectorPE(k = 16, attr_name = 'pos_enc')(data)
# data = T.AddRandomWalkPE(walk_length = 16, attr_name = 'pos_enc')(data)
data.dense_adj = to_dense_adj(data.edge_index, max_num_nodes = data.x.shape[0])[0]
data.dense_sp_matrix = dense_shortest_path_matrix.float()  # pre-computed in previous cell
data = data.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)


def train():
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.pos_enc, data.dense_sp_matrix)
    loss = F.nll_loss(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    return float(loss)


@torch.no_grad()
def test():
    model.eval()
    pred, accs = model(data.x, data.pos_enc, data.dense_sp_matrix).argmax(dim=-1), []
    for _, mask in data('train_mask', 'val_mask', 'test_mask'):
        accs.append(int((pred[mask] == data.y[mask]).sum()) / int(mask.sum()))
    return accs


best_val_acc = test_acc = 0
times = []
for epoch in range(1, 100):
    start = time.time()
    loss = train()
    train_acc, val_acc, tmp_test_acc = test()
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        test_acc = tmp_test_acc
    print(f'Epoch: {epoch:04d}, Loss: {loss:.4f} Train: {train_acc:.4f}, '
          f'Val: {val_acc:.4f}, Test: {tmp_test_acc:.4f}, '
          f'Final Test: {test_acc:.4f}')
    times.append(time.time() - start)
print(f"Median time per epoch: {torch.tensor(times).median():.4f}s")

# Notes
# - Dense Transformer needs to be trained for a bit longer to reach low loss value
# - Node positional encodings are not particularly useful
# - Edge distance encodings are very useful
# - Since Cora is highly homophilic, it is important to bias the attention towards nearby nodes
# Out:
# Epoch: 0001, Loss: 1.9466 Train: 0.5643, Val: 0.2660, Test: 0.2670, Final Test: 0.2670
# Epoch: 0002, Loss: 1.8866 Train: 0.8500, Val: 0.3860, Test: 0.3550, Final Test: 0.3550
# Epoch: 0003, Loss: 1.8286 Train: 0.9286, Val: 0.4580, Test: 0.4280, Final Test: 0.4280
# Epoch: 0004, Loss: 1.7715 Train: 0.9714, Val: 0.5320, Test: 0.5050, Final Test: 0.5050
# Epoch: 0005, Loss: 1.7114 Train: 0.9929, Val: 0.5820, Test: 0.5620, Final Test: 0.5620
# Epoch: 0006, Loss: 1.6447 Train: 1.0000, Val: 0.6200, Test: 0.5940, Final Test: 0.5940
# Epoch: 0007, Loss: 1.5750 Train: 1.0000, Val: 0.6360, Test: 0.6130, Final Test: 0.6130
# Epoch: 0008, Loss: 1.5013 Train: 1.0000, Val: 0.6480, Test: 0.6300, Final Test: 0.6300
# Epoch: 0009, Loss: 1.4139 Train: 1.0000, Val: 0.6660, Test: 0.6360, Final Test: 0.6360
# Epoch: 0010, Loss: 1.3326 Train: 1.0000, Val: 0.6580, Test: 0.6390, Final Test: 0.6360
# Epoch: 0011, Loss: 1.2422 Train: 1.0000, Val: 0.6620, Test: 0.6440, Final Test: 0.6360
# Epoch: 0012, Loss: 1.1256 Train: 1.0000, Val: 0.6620, Test: 0.6480, Final Test: 0.6360
# Epoch: 0013, Loss: 1.0354 Train: 1.0000, Val: 0.6720, Test: 0.6490, Final Test: 0.6490
# Epoch: 0014, Loss: 0.9109 Train: 1.0000, Val: 0.6740, Test: 0.6490, Final Test: 0.6490
# Epoch: 0015, Loss: 0.8277 Train: 1.0000, Val: 0.6680, Test: 0.6510, Final Test: 0.6490
# Epoch: 0016, Loss: 0.7218 Train: 1.0000, Val: 0.6560, Test: 0.6550, Final Test: 0.6490
# Epoch: 0017, Loss: 0.6168 Train: 1.0000, Val: 0.6620, Test: 0.6620, Final Test: 0.6490
# Epoch: 0018, Loss: 0.5254 Train: 1.0000, Val: 0.6760, Test: 0.6710, Final Test: 0.6710
# Epoch: 0019, Loss: 0.4446 Train: 1.0000, Val: 0.7000, Test: 0.6880, Final Test: 0.6880
# Epoch: 0020, Loss: 0.3407 Train: 1.0000, Val: 0.7260, Test: 0.7230, Final Test: 0.7230
# Epoch: 0021, Loss: 0.2607 Train: 1.0000, Val: 0.7400, Test: 0.7400, Final Test: 0.7400
# Epoch: 0022, Loss: 0.2175 Train: 1.0000, Val: 0.7560, Test: 0.7580, Final Test: 0.7580
# Epoch: 0023, Loss: 0.1674 Train: 1.0000, Val: 0.7580, Test: 0.7830, Final Test: 0.7830
# Epoch: 0024, Loss: 0.1143 Train: 1.0000, Val: 0.7760, Test: 0.8010, Final Test: 0.8010
# Epoch: 0025, Loss: 0.1070 Train: 1.0000, Val: 0.7780, Test: 0.8000, Final Test: 0.8000
# Epoch: 0026, Loss: 0.0715 Train: 1.0000, Val: 0.7880, Test: 0.7970, Final Test: 0.7970
# Epoch: 0027, Loss: 0.0548 Train: 1.0000, Val: 0.7900, Test: 0.7970, Final Test: 0.7970
# Epoch: 0028, Loss: 0.0402 Train: 1.0000, Val: 0.7820, Test: 0.7960, Final Test: 0.7970
# Epoch: 0029, Loss: 0.0435 Train: 1.0000, Val: 0.7860, Test: 0.7960, Final Test: 0.7970
# Epoch: 0030, Loss: 0.0198 Train: 1.0000, Val: 0.7800, Test: 0.7840, Final Test: 0.7970
# Epoch: 0031, Loss: 0.0364 Train: 1.0000, Val: 0.7700, Test: 0.7640, Final Test: 0.7970
# Epoch: 0032, Loss: 0.0274 Train: 1.0000, Val: 0.7440, Test: 0.7470, Final Test: 0.7970
# Epoch: 0033, Loss: 0.0301 Train: 1.0000, Val: 0.7340, Test: 0.7250, Final Test: 0.7970
# Epoch: 0034, Loss: 0.0321 Train: 1.0000, Val: 0.7280, Test: 0.7270, Final Test: 0.7970
# Epoch: 0035, Loss: 0.0313 Train: 1.0000, Val: 0.7360, Test: 0.7340, Final Test: 0.7970
# Epoch: 0036, Loss: 0.0449 Train: 1.0000, Val: 0.7440, Test: 0.7520, Final Test: 0.7970
# Epoch: 0037, Loss: 0.0108 Train: 1.0000, Val: 0.7480, Test: 0.7620, Final Test: 0.7970
# Epoch: 0038, Loss: 0.0151 Train: 1.0000, Val: 0.7540, Test: 0.7690, Final Test: 0.7970
# Epoch: 0039, Loss: 0.0101 Train: 1.0000, Val: 0.7580, Test: 0.7640, Final Test: 0.7970
# Epoch: 0040, Loss: 0.0266 Train: 1.0000, Val: 0.7500, Test: 0.7610, Final Test: 0.7970
# Epoch: 0041, Loss: 0.0233 Train: 1.0000, Val: 0.7420, Test: 0.7620, Final Test: 0.7970
# Epoch: 0042, Loss: 0.0122 Train: 1.0000, Val: 0.7460, Test: 0.7630, Final Test: 0.7970
# Epoch: 0043, Loss: 0.0108 Train: 1.0000, Val: 0.7540, Test: 0.7650, Final Test: 0.7970
# Epoch: 0044, Loss: 0.0081 Train: 1.0000, Val: 0.7580, Test: 0.7740, Final Test: 0.7970
# Epoch: 0045, Loss: 0.0100 Train: 1.0000, Val: 0.7680, Test: 0.7790, Final Test: 0.7970
# Epoch: 0046, Loss: 0.0069 Train: 1.0000, Val: 0.7740, Test: 0.7760, Final Test: 0.7970
# Epoch: 0047, Loss: 0.0052 Train: 1.0000, Val: 0.7800, Test: 0.7780, Final Test: 0.7970
# Epoch: 0048, Loss: 0.0082 Train: 1.0000, Val: 0.7840, Test: 0.7860, Final Test: 0.7970
# Epoch: 0049, Loss: 0.0081 Train: 1.0000, Val: 0.7860, Test: 0.7860, Final Test: 0.7970
# Epoch: 0050, Loss: 0.0036 Train: 1.0000, Val: 0.7860, Test: 0.7820, Final Test: 0.7970
# Epoch: 0051, Loss: 0.0028 Train: 1.0000, Val: 0.7780, Test: 0.7830, Final Test: 0.7970
# Epoch: 0052, Loss: 0.0179 Train: 1.0000, Val: 0.7740, Test: 0.7790, Final Test: 0.7970
# Epoch: 0053, Loss: 0.0053 Train: 1.0000, Val: 0.7720, Test: 0.7810, Final Test: 0.7970
# Epoch: 0054, Loss: 0.0021 Train: 1.0000, Val: 0.7760, Test: 0.7830, Final Test: 0.7970
# Epoch: 0055, Loss: 0.0046 Train: 1.0000, Val: 0.7760, Test: 0.7780, Final Test: 0.7970
# Epoch: 0056, Loss: 0.0034 Train: 1.0000, Val: 0.7700, Test: 0.7730, Final Test: 0.7970
# Epoch: 0057, Loss: 0.0045 Train: 1.0000, Val: 0.7680, Test: 0.7650, Final Test: 0.7970
# Epoch: 0058, Loss: 0.0025 Train: 1.0000, Val: 0.7680, Test: 0.7650, Final Test: 0.7970
# Epoch: 0059, Loss: 0.0041 Train: 1.0000, Val: 0.7700, Test: 0.7650, Final Test: 0.7970
# Epoch: 0060, Loss: 0.0095 Train: 1.0000, Val: 0.7700, Test: 0.7650, Final Test: 0.7970
# Epoch: 0061, Loss: 0.0159 Train: 1.0000, Val: 0.7700, Test: 0.7660, Final Test: 0.7970
# Epoch: 0062, Loss: 0.0025 Train: 1.0000, Val: 0.7620, Test: 0.7670, Final Test: 0.7970
# Epoch: 0063, Loss: 0.0027 Train: 1.0000, Val: 0.7600, Test: 0.7680, Final Test: 0.7970
# Epoch: 0064, Loss: 0.0019 Train: 1.0000, Val: 0.7620, Test: 0.7680, Final Test: 0.7970
# Epoch: 0065, Loss: 0.0021 Train: 1.0000, Val: 0.7640, Test: 0.7710, Final Test: 0.7970
# Epoch: 0066, Loss: 0.0015 Train: 1.0000, Val: 0.7560, Test: 0.7720, Final Test: 0.7970
# Epoch: 0067, Loss: 0.0022 Train: 1.0000, Val: 0.7540, Test: 0.7720, Final Test: 0.7970
# Epoch: 0068, Loss: 0.0017 Train: 1.0000, Val: 0.7560, Test: 0.7700, Final Test: 0.7970
# Epoch: 0069, Loss: 0.0029 Train: 1.0000, Val: 0.7600, Test: 0.7740, Final Test: 0.7970
# Epoch: 0070, Loss: 0.0041 Train: 1.0000, Val: 0.7600, Test: 0.7750, Final Test: 0.7970
# Epoch: 0071, Loss: 0.0057 Train: 1.0000, Val: 0.7600, Test: 0.7740, Final Test: 0.7970
# Epoch: 0072, Loss: 0.0020 Train: 1.0000, Val: 0.7620, Test: 0.7730, Final Test: 0.7970
# Epoch: 0073, Loss: 0.0026 Train: 1.0000, Val: 0.7640, Test: 0.7720, Final Test: 0.7970
# Epoch: 0074, Loss: 0.0023 Train: 1.0000, Val: 0.7640, Test: 0.7720, Final Test: 0.7970
# Epoch: 0075, Loss: 0.0032 Train: 1.0000, Val: 0.7680, Test: 0.7710, Final Test: 0.7970
# Epoch: 0076, Loss: 0.0021 Train: 1.0000, Val: 0.7740, Test: 0.7760, Final Test: 0.7970
# Epoch: 0077, Loss: 0.0021 Train: 1.0000, Val: 0.7760, Test: 0.7770, Final Test: 0.7970
# Epoch: 0078, Loss: 0.0014 Train: 1.0000, Val: 0.7780, Test: 0.7790, Final Test: 0.7970
# Epoch: 0079, Loss: 0.0022 Train: 1.0000, Val: 0.7800, Test: 0.7830, Final Test: 0.7970
# Epoch: 0080, Loss: 0.0023 Train: 1.0000, Val: 0.7800, Test: 0.7820, Final Test: 0.7970
# Epoch: 0081, Loss: 0.0028 Train: 1.0000, Val: 0.7760, Test: 0.7830, Final Test: 0.7970
# Epoch: 0082, Loss: 0.0015 Train: 1.0000, Val: 0.7760, Test: 0.7820, Final Test: 0.7970
# Epoch: 0083, Loss: 0.0013 Train: 1.0000, Val: 0.7800, Test: 0.7800, Final Test: 0.7970
# Epoch: 0084, Loss: 0.0015 Train: 1.0000, Val: 0.7800, Test: 0.7800, Final Test: 0.7970
# Epoch: 0085, Loss: 0.0014 Train: 1.0000, Val: 0.7800, Test: 0.7810, Final Test: 0.7970
# Epoch: 0086, Loss: 0.0013 Train: 1.0000, Val: 0.7800, Test: 0.7800, Final Test: 0.7970
# Epoch: 0087, Loss: 0.0008 Train: 1.0000, Val: 0.7780, Test: 0.7800, Final Test: 0.7970
# Epoch: 0088, Loss: 0.0014 Train: 1.0000, Val: 0.7800, Test: 0.7810, Final Test: 0.7970
# Epoch: 0089, Loss: 0.0020 Train: 1.0000, Val: 0.7800, Test: 0.7810, Final Test: 0.7970
# Epoch: 0090, Loss: 0.0010 Train: 1.0000, Val: 0.7800, Test: 0.7830, Final Test: 0.7970
# Epoch: 0091, Loss: 0.0010 Train: 1.0000, Val: 0.7800, Test: 0.7830, Final Test: 0.7970
# Epoch: 0092, Loss: 0.0018 Train: 1.0000, Val: 0.7800, Test: 0.7830, Final Test: 0.7970
# Epoch: 0093, Loss: 0.0016 Train: 1.0000, Val: 0.7800, Test: 0.7860, Final Test: 0.7970
# Epoch: 0094, Loss: 0.0009 Train: 1.0000, Val: 0.7760, Test: 0.7850, Final Test: 0.7970
# Epoch: 0095, Loss: 0.0017 Train: 1.0000, Val: 0.7780, Test: 0.7850, Final Test: 0.7970
# Epoch: 0096, Loss: 0.0011 Train: 1.0000, Val: 0.7740, Test: 0.7850, Final Test: 0.7970
# Epoch: 0097, Loss: 0.0018 Train: 1.0000, Val: 0.7740, Test: 0.7840, Final Test: 0.7970
# Epoch: 0098, Loss: 0.0068 Train: 1.0000, Val: 0.7740, Test: 0.7840, Final Test: 0.7970
# Epoch: 0099, Loss: 0.0007 Train: 1.0000, Val: 0.7760, Test: 0.7820, Final Test: 0.7970
# Median time per epoch: 0.0721s
